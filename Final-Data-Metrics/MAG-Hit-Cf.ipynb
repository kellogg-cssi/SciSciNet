# %%
import pandas as pd
date_str = '2021-12-06'

# %%
# %%time
df_MAG_Sel_wRC = pd.read_csv("../Final-Data/Data-Tables-MAG_" + date_str + "/df_MAG_Sel_wRC.csv", sep='\t')
df_MAG_Sel_wRC
# Sel_MAG_Ref_Cite.ipynb
# Out:
# CPU times: user 2min 52s, sys: 35 s, total: 3min 27s
# Wall time: 3min 27s
#                 MAGID                               DOI     DocType    Year  \
# 0             2789336                               NaN     Journal  2008.0
# 1             9552966                               NaN     Journal  2005.0
# 2             9694411                               NaN  Conference  1994.0
# 3            14355006                               NaN  Repository  2011.0
# 4            14558443      10.1007/978-3-662-45174-8_28  Conference  2014.0
# ...               ...                               ...         ...     ...
# 134129183  3215499129  10.1109/ICRERA52334.2021.9598593         NaN  2021.0
# 134129184  3215845741          10.3389/FCVM.2021.766676     Journal  2021.0
# 134129185  3216186450       10.1016/J.IDNOW.2021.11.004         NaN  2021.0
# 134129186  3216762448      10.1016/J.ISTRUC.2021.10.095     Journal  2022.0
# ...

# %%
# %%time
df_MAG_PF_Lv0_Sel = pd.read_csv("../Final-Data/Data-Tables-MAG_" + date_str + "/df_MAG_PF_Lv0_Sel.csv", sep='\t')
df_MAG_PF_Lv0_Sel
# Read_MAG_Paper_Fields.ipynb
# Out:
# CPU times: user 26 s, sys: 746 ms, total: 26.8 s
# Wall time: 26.8 s
#                     0          1         2
# 0            18936224   71924100  0.304275
# 1            94748468  144024400  0.450289
# 2           113998959   71924100  0.284752
# 3            56740461  144133560  0.432024
# 4                  23   71924100  0.443839
# ...               ...        ...       ...
# 116942136  3204507145   41008148  0.461706
# 116942137  3204507150  185592680  0.387695
# 116942138  3204507160   71924100  0.432389
# 116942139  3204507164   71924100  0.369905
# 116942140  3204507171  144133560  0.443296
#
# [116942141 rows x 3 columns]

# %%
# %%time
df_MAG_PF_Lv1_Sel = pd.read_csv("../Final-Data/Data-Tables-MAG_" + date_str + "/df_MAG_PF_Lv1_Sel.csv", sep='\t')
df_MAG_PF_Lv1_Sel
# Read_MAG_Paper_Fields.ipynb
# Out:
# CPU times: user 35.7 s, sys: 2.33 s, total: 38 s
# Wall time: 38.1 s
#                     0          1         2
# 0            94748468   95124753  0.450859
# 1            94748468   36289849  0.440132
# 2           113998959  112930515  0.397371
# 3                  23  177713679  0.441617
# 4            56740461  136264566  0.433773
# ...               ...        ...       ...
# 160552848  3204507150  188027245  0.438061
# 160552849  3204507160  187212893  0.446144
# 160552850  3204507164  143998085  0.397296
# 160552851  3204507164  126322002  0.000000
# 160552852  3204507171   34447519  0.473507
#
# [160552853 rows x 3 columns]

# %%
df_MAG_Sel_wRC
# Out:
#                 MAGID                               DOI     DocType    Year  \
# 0             2789336                               NaN     Journal  2008.0
# 1             9552966                               NaN     Journal  2005.0
# 2             9694411                               NaN  Conference  1994.0
# 3            14355006                               NaN  Repository  2011.0
# 4            14558443      10.1007/978-3-662-45174-8_28  Conference  2014.0
# ...               ...                               ...         ...     ...
# 134129183  3215499129  10.1109/ICRERA52334.2021.9598593         NaN  2021.0
# 134129184  3215845741          10.3389/FCVM.2021.766676     Journal  2021.0
# 134129185  3216186450       10.1016/J.IDNOW.2021.11.004         NaN  2021.0
# 134129186  3216762448      10.1016/J.ISTRUC.2021.10.095     Journal  2022.0
# 134129187  3217727977     10.1109/MLISE54096.2021.00043  Conference  2021.0
#
# ...

# %%
df_MAG_PF_Lv0_Sel['0']
# Out:
# 0              18936224
# 1              94748468
# 2             113998959
# 3              56740461
# 4                    23
#                 ...
# 116942136    3204507145
# 116942137    3204507150
# 116942138    3204507160
# 116942139    3204507164
# 116942140    3204507171
# Name: 0, Length: 116942141, dtype: int64

# %%
df_MAG_PF_Lv0_Sel.rename(columns={'0':'MAGID','1':'FieldID','2':'ConfScore'}, inplace=True)
df_MAG_PF_Lv0_Sel
# Out:
#                 MAGID    FieldID  ConfScore
# 0            18936224   71924100   0.304275
# 1            94748468  144024400   0.450289
# 2           113998959   71924100   0.284752
# 3            56740461  144133560   0.432024
# 4                  23   71924100   0.443839
# ...               ...        ...        ...
# 116942136  3204507145   41008148   0.461706
# 116942137  3204507150  185592680   0.387695
# 116942138  3204507160   71924100   0.432389
# 116942139  3204507164   71924100   0.369905
# 116942140  3204507171  144133560   0.443296
#
# [116942141 rows x 3 columns]

# %%
df_MAG_PF_Lv1_Sel.rename(columns={'0':'MAGID','1':'FieldID','2':'ConfScore'}, inplace=True)
df_MAG_PF_Lv1_Sel
# Out:
#                 MAGID    FieldID  ConfScore
# 0            94748468   95124753   0.450859
# 1            94748468   36289849   0.440132
# 2           113998959  112930515   0.397371
# 3                  23  177713679   0.441617
# 4            56740461  136264566   0.433773
# ...               ...        ...        ...
# 160552848  3204507150  188027245   0.438061
# 160552849  3204507160  187212893   0.446144
# 160552850  3204507164  143998085   0.397296
# 160552851  3204507164  126322002   0.000000
# 160552852  3204507171   34447519   0.473507
#
# [160552853 rows x 3 columns]

# %%
# %%time
df_MAG_PF_Year_Lv0 = df_MAG_PF_Lv0_Sel[['MAGID','FieldID']].merge(
    df_MAG_Sel_wRC[['MAGID','Year','C_all']], how='inner', on='MAGID')
df_MAG_PF_Year_Lv0
# Out:
# CPU times: user 2min 5s, sys: 11.6 s, total: 2min 17s
# Wall time: 2min 17s
#                 MAGID    FieldID    Year  C_all
# 0            18936224   71924100  2009.0   11.0
# 1            94748468  144024400  2000.0    0.0
# 2           113998959   71924100  2003.0    6.0
# 3            56740461  144133560  1995.0    5.0
# 4                  23   71924100  2012.0    2.0
# ...               ...        ...     ...    ...
# 116942136  3204507145   41008148  2021.0    0.0
# 116942137  3204507150  185592680  2022.0    0.0
# 116942138  3204507160   71924100  2021.0    0.0
# 116942139  3204507164   71924100  2021.0    0.0
# 116942140  3204507171  144133560  2021.0    0.0
#
# [116942141 rows x 4 columns]

# %%
# %%time
df_MAG_PF_Year_Lv1 = df_MAG_PF_Lv1_Sel[['MAGID','FieldID']].merge(
    df_MAG_Sel_wRC[['MAGID','Year','C_all']], how='inner', on='MAGID')
df_MAG_PF_Year_Lv1
# Out:
# CPU times: user 1min 59s, sys: 12.8 s, total: 2min 12s
# Wall time: 2min 12s
#                 MAGID    FieldID    Year  C_all
# 0            94748468   95124753  2000.0    0.0
# 1            94748468   36289849  2000.0    0.0
# 2           113998959  112930515  2003.0    6.0
# 3           113998959  141071460  2003.0    6.0
# 4                  23  177713679  2012.0    2.0
# ...               ...        ...     ...    ...
# 160552848  3204507150  188027245  2022.0    0.0
# 160552849  3204507160  187212893  2021.0    0.0
# 160552850  3204507164  143998085  2021.0    0.0
# 160552851  3204507164  126322002  2021.0    0.0
# 160552852  3204507171   34447519  2021.0    0.0
#
# [160552853 rows x 4 columns]

# %% [markdown]
# # Multi-field Analysis

# %%
# %%time
df_MAG_PF_Year_Lv0_cnt = df_MAG_PF_Year_Lv0.groupby(
    ['MAGID'], as_index=False)['FieldID'].agg(['count']).reset_index().sort_values(['count'], ascending=False)
df_MAG_PF_Year_Lv0_cnt
# Counting how many fields are in a paper
# Out:
# CPU times: user 1min 13s, sys: 5.74 s, total: 1min 19s
# Wall time: 1min 19s
#                 MAGID  count
# 92454063   2890728016      5
# 54257913   2170098304      5
# 4662729     565040976      5
# 19649064   1987244015      5
# 4401661     393867193      5
# ...               ...    ...
# 38976605   2068628046      1
# 38976604   2068628031      1
# 38976603   2068628030      1
# 38976602   2068628029      1
# 116908233  3217811007      1
#
# [116908234 rows x 2 columns]

# %%
df_MAG_PF_Year_Lv0_cnt.rename(columns={'count':'Field_count'},inplace=True)
df_MAG_PF_Year_Lv0_cnt
# Out:
#                 MAGID  Field_count
# 92454063   2890728016            5
# 54257913   2170098304            5
# 4662729     565040976            5
# 19649064   1987244015            5
# 4401661     393867193            5
# ...               ...          ...
# 38976605   2068628046            1
# 38976604   2068628031            1
# 38976603   2068628030            1
# 38976602   2068628029            1
# 116908233  3217811007            1
#
# [116908234 rows x 2 columns]

# %%
# %%time
df_MAG_PF_Year_Lv0_cnt2 = df_MAG_PF_Year_Lv0_cnt.groupby(['Field_count'])['MAGID'].agg(
    ['count']).reset_index().sort_values(['count'], ascending=False)
df_MAG_PF_Year_Lv0_cnt2
# Out:
# CPU times: user 1.81 s, sys: 220 ms, total: 2.03 s
# Wall time: 2.03 s
#    Field_count      count
# 0            1  116875250
# 1            2      32134
# 2            3        782
# 3            4         63
# 4            5          5

# %%
df_MAG_PF_Year_Lv1
# Out:
#                 MAGID    FieldID    Year  C_all
# 0            94748468   95124753  2000.0    0.0
# 1            94748468   36289849  2000.0    0.0
# 2           113998959  112930515  2003.0    6.0
# 3           113998959  141071460  2003.0    6.0
# 4                  23  177713679  2012.0    2.0
# ...               ...        ...     ...    ...
# 160552848  3204507150  188027245  2022.0    0.0
# 160552849  3204507160  187212893  2021.0    0.0
# 160552850  3204507164  143998085  2021.0    0.0
# 160552851  3204507164  126322002  2021.0    0.0
# 160552852  3204507171   34447519  2021.0    0.0
#
# [160552853 rows x 4 columns]

# %%
# %%time
df_MAG_PF_Year_Lv1_cnt = df_MAG_PF_Year_Lv1.groupby(
    ['MAGID'], as_index=False)['FieldID'].agg(['count']).reset_index().sort_values(['count'], ascending=False)
df_MAG_PF_Year_Lv1_cnt
# Counting how many fields are in a paper
# Out:
# CPU times: user 1min 15s, sys: 5.77 s, total: 1min 21s
# Wall time: 1min 21s
#                 MAGID  count
# 69918620   2402678651      6
# 97774167   2969097548      6
# 68472079   2390551814      6
# 10341837   1581640613      6
# 41621965   2082081125      6
# ...               ...    ...
# 51510174   2151796457      1
# 51510172   2151796449      1
# 51510169   2151796412      1
# 51510166   2151796393      1
# 115871938  3217811007      1
#
# [115871939 rows x 2 columns]

# %%
df_MAG_PF_Year_Lv1_cnt.rename(columns={'count':'Field_count'},inplace=True)
df_MAG_PF_Year_Lv1_cnt
# Out:
#                 MAGID  Field_count
# 69918620   2402678651            6
# 97774167   2969097548            6
# 68472079   2390551814            6
# 10341837   1581640613            6
# 41621965   2082081125            6
# ...               ...          ...
# 51510174   2151796457            1
# 51510172   2151796449            1
# 51510169   2151796412            1
# 51510166   2151796393            1
# 115871938  3217811007            1
#
# [115871939 rows x 2 columns]

# %%
# %%time
df_MAG_PF_Year_Lv1_cnt2 = df_MAG_PF_Year_Lv1_cnt.groupby(['Field_count'])['MAGID'].agg(
    ['count']).reset_index().sort_values(['count'], ascending=False)
df_MAG_PF_Year_Lv1_cnt2
# Out:
# CPU times: user 1.96 s, sys: 208 ms, total: 2.17 s
# Wall time: 2.16 s
#    Field_count     count
# 0            1  74451051
# 1            2  38202007
# 2            3   3178336
# 3            4     39957
# 4            5       576
# 5            6        12

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
colors = [i for i in cm.get_cmap('tab20').colors]
fig, ax1 = plt.subplots(1,2,figsize=(12, 8))
ax1 = ax1.ravel()
x = np.arange(5) + 1
i = 0

ax1[i].bar(df_MAG_PF_Year_Lv0_cnt2['Field_count'].values, 
        df_MAG_PF_Year_Lv0_cnt2['count'].values,
        color=colors[0])
ax1[i].set_xlabel('Lv0 Field counts', fontsize=16)
ax1[i].set_ylabel('MAG Paper counts', fontsize=16)
ax1[i].set_yscale('log')
ax1[i].tick_params(axis='y', labelsize=12)
ax1[i].tick_params(axis='x', labelsize=12)

i += 1

ax1[i].bar(df_MAG_PF_Year_Lv1_cnt2['Field_count'].values, 
        df_MAG_PF_Year_Lv1_cnt2['count'].values,
        color=colors[0])
ax1[i].set_xlabel('Lv1 Field counts', fontsize=16)
ax1[i].set_ylabel('MAG Paper counts', fontsize=16)
ax1[i].set_yscale('log')
ax1[i].tick_params(axis='y', labelsize=12)
ax1[i].tick_params(axis='x', labelsize=12)

# ax1.set_xscale('log')

# %% [markdown]
# # Calculation of Hit Rate!

# %%
# %%time
import csv
import pandas as pd

date_str = '2021-12-06'

df_MAG_F = pd.read_csv('../../MAG_'+date_str+'/advanced/FieldsOfStudy.txt', sep='\t', header=None, 
                     quoting=csv.QUOTE_NONE)

df_MAG_F
# Out:
# CPU times: user 1.33 s, sys: 73 ms, total: 1.4 s
# Wall time: 1.44 s
#                  0      1                          2  \
# 0           417682  16941                  night air
# 1          1443462  16012                immobiliser
# 2          1576492  12988              matrix pencil
# 3          2657588  13563     combinatorial topology
# 4          3079626   8615    quantum electrodynamics
# ...            ...    ...                        ...
# 714966  3020516982  15210           cholesterol diet
# 714967  3020525681  16911    community connectedness
# 714968  3020532668  14800                pre cooling
# 714969  3020562556  14742  image guided radiotherapy
# 714970  3020702029  15527             short implants
#
#                                 3    4  5       6       7        8           9
# 0                       Night air  NaN  2     104     103      428  2016-06-24
# 1                     Immobiliser  NaN  2     220     215     1028  2016-06-24
# ...

# %%
df_MAG_F_Lv0 = df_MAG_F.loc[df_MAG_F[5] < 1, :]
df_MAG_F_Lv0
# Out:
#                 0     1                      2                      3  \
# 17405    95457728  6857                history                History
# 23106   127313418  5739                geology                Geology
# 66244   162324750  6154              economics              Economics
# 140540  205649164  6309              geography              Geography
# 203361  185592680  4361              chemistry              Chemistry
# 223318  138885662  7302             philosophy             Philosophy
# 234746  144024400  6131              sociology              Sociology
# 234806  192562407  4156      materials science      Materials science
# 263208   33923547  5140            mathematics            Mathematics
# 286322   86803240  4437                biology                Biology
# 394647   41008148  4251       computer science       Computer science
# 429091   17744445  6005      political science      Political science
# ...

# %%
df_MAG_F_Lv1 = df_MAG_F.loc[df_MAG_F[5] == 1, :]
df_MAG_F_Lv1
# Out:
#                 0     1                        2                        3  \
# 4         3079626  8615  quantum electrodynamics  Quantum electrodynamics
# 39       37914503  8015     mathematical physics     Mathematical physics
# 144     159047783  7067                 virology                 Virology
# 2938     70410870  7376      clinical psychology      Clinical psychology
# 3056    187212893  7125               pediatrics               Pediatrics
# ...           ...   ...                      ...                      ...
# 706592   70721500  7817    computational biology    Computational biology
# 709346   42360764  6302     chemical engineering     Chemical engineering
# 709476  178550888  9585  business administration  Business administration
# 712102   13736549  9671   industrial engineering   Industrial engineering
# 712135   47768531  8323    development economics    Development economics
#
#                                  4  5        6        7         8           9
# ...

# %% [markdown]
# ## Lv0 Field Papers

# %%
df_MAG_PF_Year_Lv0
# Out:
#                 MAGID    FieldID    Year  C_all
# 0            18936224   71924100  2009.0   11.0
# 1            94748468  144024400  2000.0    0.0
# 2           113998959   71924100  2003.0    6.0
# 3            56740461  144133560  1995.0    5.0
# 4                  23   71924100  2012.0    2.0
# ...               ...        ...     ...    ...
# 116942136  3204507145   41008148  2021.0    0.0
# 116942137  3204507150  185592680  2022.0    0.0
# 116942138  3204507160   71924100  2021.0    0.0
# 116942139  3204507164   71924100  2021.0    0.0
# 116942140  3204507171  144133560  2021.0    0.0
#
# [116942141 rows x 4 columns]

# %%
df_MAG_PF_Year_Lv0 = df_MAG_PF_Year_Lv0.loc[pd.notnull(df_MAG_PF_Year_Lv0['Year']),:]
df_MAG_PF_Year_Lv0
# Out:
#                 MAGID    FieldID    Year  C_all
# 0            18936224   71924100  2009.0   11.0
# 1            94748468  144024400  2000.0    0.0
# 2           113998959   71924100  2003.0    6.0
# 3            56740461  144133560  1995.0    5.0
# 4                  23   71924100  2012.0    2.0
# ...               ...        ...     ...    ...
# 116942136  3204507145   41008148  2021.0    0.0
# 116942137  3204507150  185592680  2022.0    0.0
# 116942138  3204507160   71924100  2021.0    0.0
# 116942139  3204507164   71924100  2021.0    0.0
# 116942140  3204507171  144133560  2021.0    0.0
#
# [116937951 rows x 4 columns]

# %%
df_MAG_PF_Year_Lv0_GBF = df_MAG_PF_Year_Lv0.groupby(['FieldID'],as_index=False)

# %%
df_MAG_PF_Year_Lv0
# Out:
#                 MAGID    FieldID    Year  C_all
# 0            18936224   71924100  2009.0   11.0
# 1            94748468  144024400  2000.0    0.0
# 2           113998959   71924100  2003.0    6.0
# 3            56740461  144133560  1995.0    5.0
# 4                  23   71924100  2012.0    2.0
# ...               ...        ...     ...    ...
# 116942136  3204507145   41008148  2021.0    0.0
# 116942137  3204507150  185592680  2022.0    0.0
# 116942138  3204507160   71924100  2021.0    0.0
# 116942139  3204507164   71924100  2021.0    0.0
# 116942140  3204507171  144133560  2021.0    0.0
#
# [116937951 rows x 4 columns]

# %%
# %%time
from tqdm import tqdm
import copy
Chunks = []
for field, df_group in tqdm(df_MAG_PF_Year_Lv0_GBF):
    # print(field)
    df_MAG_PF_Year_Lv0_GBFY = df_group.groupby(['Year'],as_index=False)
    # for year, df_G in tqdm(df_MAG_PF_Year_Lv0_GBFY):
    for year, df_G in df_MAG_PF_Year_Lv0_GBFY:
        # print(year)
        df_G = df_G.sort_values(by=['C_all'],ascending=False)
        len_df_G = len(df_G)
        
        pct = 0.01
        df_G['Lv0_1pct_Hit'] = 0

        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] >= bound_c, 'Lv0_1pct_Hit'] = 1
        
        pct = 0.05
        df_G['Lv0_5pct_Hit'] = 0
        
        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] >= bound_c, 'Lv0_5pct_Hit'] = 1
        
        
        pct = 0.10
        df_G['Lv0_10pct_Hit'] = 0
        
        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] >= bound_c, 'Lv0_10pct_Hit'] = 1
        
        
        # Chunks.append(copy.deepcopy(df_G))
        Chunks.append(df_G)
        # break
    # break
# df_G
# Out:
# 100%|██████████| 19/19 [00:44<00:00,  2.34s/it]
# CPU times: user 38.7 s, sys: 5.8 s, total: 44.5 s
# Wall time: 44.4 s

# %%
# %%time
df_MAG_Lv0_Hit = pd.concat(Chunks, ignore_index=True)
df_MAG_Lv0_Hit
# Out:
# CPU times: user 1.8 s, sys: 2.31 s, total: 4.11 s
# Wall time: 4.12 s
#                 MAGID    FieldID    Year  C_all  Lv0_1pct_Hit  Lv0_5pct_Hit  \
# 0          2125825908   15744967  1800.0    2.0             1             1
# 1          3207565320   15744967  1800.0    1.0             0             1
# 2          3205046361   15744967  1800.0    1.0             0             1
# 3           638928283   15744967  1800.0    0.0             0             0
# 4          3207300303   15744967  1800.0    0.0             0             0
# ...               ...        ...     ...    ...           ...           ...
# 116937946  3210175697  205649164  2022.0    0.0             0             0
# 116937947  3214688134  205649164  2022.0    0.0             0             0
# 116937948  3205848434  205649164  2022.0    0.0             0             0
# 116937949  3210152122  205649164  2022.0    0.0             0             0
# ...

# %%
# %%time
Larger_10 = len(df_MAG_Lv0_Hit.loc[df_MAG_Lv0_Hit['Lv0_10pct_Hit'] == 1, :]) / len(df_MAG_Lv0_Hit)
Larger_5 = len(df_MAG_Lv0_Hit.loc[df_MAG_Lv0_Hit['Lv0_5pct_Hit'] == 1, :]) / len(df_MAG_Lv0_Hit)
Larger_1 = len(df_MAG_Lv0_Hit.loc[df_MAG_Lv0_Hit['Lv0_1pct_Hit'] == 1, :]) / len(df_MAG_Lv0_Hit)
print(Larger_10, Larger_5, Larger_1)
# Out:
# 0.10789209911844616 0.052633622766316474 0.010137034126756676
# CPU times: user 775 ms, sys: 508 ms, total: 1.28 s
# Wall time: 1.28 s

# %%
# %%time
from tqdm import tqdm
import copy
Chunks = []
for field, df_group in tqdm(df_MAG_PF_Year_Lv0_GBF):
    # print(field)
    df_MAG_PF_Year_Lv0_GBFY = df_group.groupby(['Year'],as_index=False)
    # for year, df_G in tqdm(df_MAG_PF_Year_Lv0_GBFY):
    for year, df_G in df_MAG_PF_Year_Lv0_GBFY:
        # print(year)
        df_G = df_G.sort_values(by=['C_all'],ascending=False)
        len_df_G = len(df_G)
        
        pct = 0.01
        df_G['Lv0_1pct_Hit'] = 0

        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] > bound_c, 'Lv0_1pct_Hit'] = 1
        
        pct = 0.05
        df_G['Lv0_5pct_Hit'] = 0
        
        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] > bound_c, 'Lv0_5pct_Hit'] = 1
        
        
        pct = 0.10
        df_G['Lv0_10pct_Hit'] = 0
        
        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] > bound_c, 'Lv0_10pct_Hit'] = 1
        
        
        # Chunks.append(copy.deepcopy(df_G))
        Chunks.append(df_G)
        # break
    # break
# df_G
# Out:
# 100%|██████████| 19/19 [00:41<00:00,  2.16s/it]
# CPU times: user 41.5 s, sys: 3.32 s, total: 44.8 s
# Wall time: 44.8 s

# %%
# %%time
df_MAG_Lv0_Hit = pd.concat(Chunks, ignore_index=True)
df_MAG_Lv0_Hit
# Out:
# CPU times: user 1.91 s, sys: 1.99 s, total: 3.89 s
# Wall time: 3.89 s
#                 MAGID    FieldID    Year  C_all  Lv0_1pct_Hit  Lv0_5pct_Hit  \
# 0          2125825908   15744967  1800.0    2.0             0             1
# 1          3207565320   15744967  1800.0    1.0             0             0
# 2          3205046361   15744967  1800.0    1.0             0             0
# 3           638928283   15744967  1800.0    0.0             0             0
# 4          3207300303   15744967  1800.0    0.0             0             0
# ...               ...        ...     ...    ...           ...           ...
# 116937946  3210175697  205649164  2022.0    0.0             0             0
# 116937947  3214688134  205649164  2022.0    0.0             0             0
# 116937948  3205848434  205649164  2022.0    0.0             0             0
# 116937949  3210152122  205649164  2022.0    0.0             0             0
# ...

# %%
df_MAG_PF_Lv0_Hit_Sel = df_MAG_Lv0_Hit.loc[:,['MAGID','FieldID','Lv0_1pct_Hit','Lv0_5pct_Hit','Lv0_10pct_Hit']]
df_MAG_PF_Lv0_Hit_Sel
# Out:
#                 MAGID    FieldID  Lv0_1pct_Hit  Lv0_5pct_Hit  Lv0_10pct_Hit
# 0          2125825908   15744967             0             1              1
# 1          3207565320   15744967             0             0              1
# 2          3205046361   15744967             0             0              1
# 3           638928283   15744967             0             0              0
# 4          3207300303   15744967             0             0              0
# ...               ...        ...           ...           ...            ...
# 116937946  3210175697  205649164             0             0              0
# 116937947  3214688134  205649164             0             0              0
# 116937948  3205848434  205649164             0             0              0
# 116937949  3210152122  205649164             0             0              0
# 116937950  3217810235  205649164             0             0              0
#
# [116937951 rows x 5 columns]

# %%
df_MAG_PF_Lv0_Hit_Sel.to_csv('./Data-Metrics/MAG_PF_Lv0_Hit.csv', sep='\t', index=False)

# %%
# %%time
Smaller_10 = len(df_MAG_Lv0_Hit.loc[df_MAG_Lv0_Hit['Lv0_10pct_Hit'] == 1, :]) / len(df_MAG_Lv0_Hit)
Smaller_5 = len(df_MAG_Lv0_Hit.loc[df_MAG_Lv0_Hit['Lv0_5pct_Hit'] == 1, :]) / len(df_MAG_Lv0_Hit)
Smaller_1 = len(df_MAG_Lv0_Hit.loc[df_MAG_Lv0_Hit['Lv0_1pct_Hit'] == 1, :]) / len(df_MAG_Lv0_Hit)
print(Smaller_10, Smaller_5, Smaller_1)
# Out:
# 0.09587212623556231 0.048545189576649925 0.00982111444726785
# CPU times: user 2.66 s, sys: 2.48 s, total: 5.14 s
# Wall time: 5.21 s

# %%
print(0.1-Smaller_10, Larger_10-0.1)
print(0.05-Smaller_5, Larger_5-0.05)
print(0.01-Smaller_1, Larger_1-0.01)
# Out:
# 0.004127873764437698 0.007892099118446155
# 0.001454810423350078 0.0026336227663164707
# 0.00017888555273215014 0.00013703412675667576

# %%
df_MAG_Lv0_Hit.loc[df_MAG_Lv0_Hit['Lv0_10pct_Hit'] == 1, :]
# Out:
#                 MAGID    FieldID    Year   C_all  Lv0_1pct_Hit  Lv0_5pct_Hit  \
# 0          2125825908   15744967  1800.0     2.0             0             1
# 1          3207565320   15744967  1800.0     1.0             0             0
# 2          3205046361   15744967  1800.0     1.0             0             0
# 184        1532182548   15744967  1816.0    40.0             0             0
# 303        2132504853   15744967  1825.0  2861.0             0             0
# ...               ...        ...     ...     ...           ...           ...
# 116936727  3193707667  205649164  2022.0     1.0             0             0
# 116936728  3127230640  205649164  2022.0     1.0             0             0
# 116936729  3195668028  205649164  2022.0     1.0             0             0
# 116936730  3092828656  205649164  2022.0     1.0             0             0
# 116936731  3131048313  205649164  2022.0     1.0             0             0
#
#            Lv0_10pct_Hit
# ...

# %%
# df_MAG_Lv0_Hit.loc[(df_MAG_Lv0_Hit['FieldID'] == 205649164) & (df_MAG_Lv0_Hit['Year'] == 2022), :]

# %%
len(df_MAG_Lv0_Hit['MAGID'].unique())
# Out:
# 116904044

# %%
# %%time
df_MAG_Lv0_Hit = df_MAG_Lv0_Hit.sort_values(by=['Lv0_1pct_Hit'], ascending=True)
df_MAG_Lv0_Hit
# Out:
# CPU times: user 6.77 s, sys: 3.13 s, total: 9.9 s
# Wall time: 9.89 s
#                MAGID    FieldID    Year  C_all  Lv0_1pct_Hit  Lv0_5pct_Hit  \
# 0         2125825908   15744967  1800.0    2.0             0             1
# 77766619  2363214083  127413603  2011.0    0.0             0             0
# 77766618  2353698539  127413603  2011.0    0.0             0             0
# 77766617  2360072745  127413603  2011.0    0.0             0             0
# 77766616  2350545798  127413603  2011.0    0.0             0             0
# ...              ...        ...     ...    ...           ...           ...
# 95564873  2169029702  185592680  1986.0  561.0             1             1
# 95564874  2949306987  185592680  1986.0  561.0             1             1
# 95564875  2030581562  185592680  1986.0  560.0             1             1
# 95564857  1627505132  185592680  1986.0  578.0             1             1
# 81558959  1546685917  142362112  1979.0  247.0             1             1
# ...

# %%
# %%time
df_MAG_Lv0_Hit = df_MAG_Lv0_Hit.sort_values(by=['Lv0_5pct_Hit'], ascending=True, kind='mergesort')
df_MAG_Lv0_Hit
# Out:
# CPU times: user 4.92 s, sys: 2.88 s, total: 7.8 s
# Wall time: 7.94 s
#                MAGID    FieldID    Year  C_all  Lv0_1pct_Hit  Lv0_5pct_Hit  \
# 77766619  2363214083  127413603  2011.0    0.0             0             0
# 77766618  2353698539  127413603  2011.0    0.0             0             0
# 77766617  2360072745  127413603  2011.0    0.0             0             0
# 77766616  2350545798  127413603  2011.0    0.0             0             0
# 77766615  2350545679  127413603  2011.0    0.0             0             0
# ...              ...        ...     ...    ...           ...           ...
# 95564873  2169029702  185592680  1986.0  561.0             1             1
# 95564874  2949306987  185592680  1986.0  561.0             1             1
# 95564875  2030581562  185592680  1986.0  560.0             1             1
# 95564857  1627505132  185592680  1986.0  578.0             1             1
# 81558959  1546685917  142362112  1979.0  247.0             1             1
# ...

# %%
# %%time
df_MAG_Lv0_Hit = df_MAG_Lv0_Hit.sort_values(by=['Lv0_10pct_Hit'], ascending=True, kind='mergesort')
df_MAG_Lv0_Hit
# Out:
# CPU times: user 4.12 s, sys: 3.43 s, total: 7.55 s
# Wall time: 7.55 s
#                MAGID    FieldID    Year  C_all  Lv0_1pct_Hit  Lv0_5pct_Hit  \
# 77766619  2363214083  127413603  2011.0    0.0             0             0
# 77766618  2353698539  127413603  2011.0    0.0             0             0
# 77766617  2360072745  127413603  2011.0    0.0             0             0
# 77766616  2350545798  127413603  2011.0    0.0             0             0
# 77766615  2350545679  127413603  2011.0    0.0             0             0
# ...              ...        ...     ...    ...           ...           ...
# 95564873  2169029702  185592680  1986.0  561.0             1             1
# 95564874  2949306987  185592680  1986.0  561.0             1             1
# 95564875  2030581562  185592680  1986.0  560.0             1             1
# 95564857  1627505132  185592680  1986.0  578.0             1             1
# 81558959  1546685917  142362112  1979.0  247.0             1             1
# ...

# %%
# %%time
df_MAG_Lv0_Hit.drop_duplicates(subset=['MAGID'], keep='last', inplace=True)
df_MAG_Lv0_Hit
# Out:
#                MAGID    FieldID    Year  C_all  Lv0_1pct_Hit  Lv0_5pct_Hit  \
# 77766619  2363214083  127413603  2011.0    0.0             0             0
# 77766618  2353698539  127413603  2011.0    0.0             0             0
# 77766617  2360072745  127413603  2011.0    0.0             0             0
# 77766616  2350545798  127413603  2011.0    0.0             0             0
# 77766615  2350545679  127413603  2011.0    0.0             0             0
# ...              ...        ...     ...    ...           ...           ...
# 95564873  2169029702  185592680  1986.0  561.0             1             1
# 95564874  2949306987  185592680  1986.0  561.0             1             1
# 95564875  2030581562  185592680  1986.0  560.0             1             1
# 95564857  1627505132  185592680  1986.0  578.0             1             1
# 81558959  1546685917  142362112  1979.0  247.0             1             1
#
#           Lv0_10pct_Hit
# 77766619              0
# ...

# %%
df_MAG_Lv0_Hit_Sel = df_MAG_Lv0_Hit.loc[:,['MAGID','Lv0_1pct_Hit','Lv0_5pct_Hit','Lv0_10pct_Hit']]
df_MAG_Lv0_Hit_Sel
# Out:
#                MAGID  Lv0_1pct_Hit  Lv0_5pct_Hit  Lv0_10pct_Hit
# 77766619  2363214083             0             0              0
# 77766618  2353698539             0             0              0
# 77766617  2360072745             0             0              0
# 77766616  2350545798             0             0              0
# 77766615  2350545679             0             0              0
# ...              ...           ...           ...            ...
# 95564873  2169029702             1             1              1
# 95564874  2949306987             1             1              1
# 95564875  2030581562             1             1              1
# 95564857  1627505132             1             1              1
# 81558959  1546685917             1             1              1
#
# [116904044 rows x 4 columns]

# %%
df_MAG_Lv0_Hit_Sel.to_csv('./Data-Metrics/MAG_Lv0_Hit.csv', sep='\t', index=False)

# %% [markdown]
# ## Lv1 Field Papers

# %%
df_MAG_PF_Year_Lv1
# Out:
#                 MAGID    FieldID    Year  C_all
# 0            94748468   95124753  2000.0    0.0
# 1            94748468   36289849  2000.0    0.0
# 2           113998959  112930515  2003.0    6.0
# 3           113998959  141071460  2003.0    6.0
# 4                  23  177713679  2012.0    2.0
# ...               ...        ...     ...    ...
# 160552848  3204507150  188027245  2022.0    0.0
# 160552849  3204507160  187212893  2021.0    0.0
# 160552850  3204507164  143998085  2021.0    0.0
# 160552851  3204507164  126322002  2021.0    0.0
# 160552852  3204507171   34447519  2021.0    0.0
#
# [160552853 rows x 4 columns]

# %%
df_MAG_PF_Year_Lv1 = df_MAG_PF_Year_Lv1.loc[pd.notnull(df_MAG_PF_Year_Lv1['Year']),:]
df_MAG_PF_Year_Lv1
# Out:
#                 MAGID    FieldID    Year  C_all
# 0            94748468   95124753  2000.0    0.0
# 1            94748468   36289849  2000.0    0.0
# 2           113998959  112930515  2003.0    6.0
# 3           113998959  141071460  2003.0    6.0
# 4                  23  177713679  2012.0    2.0
# ...               ...        ...     ...    ...
# 160552848  3204507150  188027245  2022.0    0.0
# 160552849  3204507160  187212893  2021.0    0.0
# 160552850  3204507164  143998085  2021.0    0.0
# 160552851  3204507164  126322002  2021.0    0.0
# 160552852  3204507171   34447519  2021.0    0.0
#
# [160548638 rows x 4 columns]

# %%
df_MAG_PF_Year_Lv1_GBF = df_MAG_PF_Year_Lv1.groupby(['FieldID'],as_index=False)

# %%
# %%time
from tqdm import tqdm
import copy
Chunks = []
for field, df_group in tqdm(df_MAG_PF_Year_Lv1_GBF):
    # print(field)
    df_MAG_PF_Year_Lv1_GBFY = df_group.groupby(['Year'],as_index=False)
    # for year, df_G in tqdm(df_MAG_PF_Year_Lv0_GBFY):
    for year, df_G in df_MAG_PF_Year_Lv1_GBFY:
        # print(year)
        df_G = df_G.sort_values(by=['C_all'],ascending=False)
        len_df_G = len(df_G)
        
        pct = 0.01
        df_G['Lv1_1pct_Hit'] = 0

        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] >= bound_c, 'Lv1_1pct_Hit'] = 1
        
        pct = 0.05
        df_G['Lv1_5pct_Hit'] = 0
        
        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] >= bound_c, 'Lv1_5pct_Hit'] = 1
        
        
        pct = 0.10
        df_G['Lv1_10pct_Hit'] = 0
        
        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] >= bound_c, 'Lv1_10pct_Hit'] = 1
        
        
        # Chunks.append(copy.deepcopy(df_G))
        Chunks.append(df_G)
        # break
    # break
# df_G
# Out:
# 100%|██████████| 292/292 [03:25<00:00,  1.42it/s]
# CPU times: user 3min 27s, sys: 6.99 s, total: 3min 34s
# Wall time: 3min 33s

# %%
# %%time
df_MAG_Lv1_Hit = pd.concat(Chunks, ignore_index=True)
df_MAG_Lv1_Hit
# Out:
# CPU times: user 9.5 s, sys: 2.92 s, total: 12.4 s
# Wall time: 12.4 s
#                 MAGID     FieldID    Year  C_all  Lv1_1pct_Hit  Lv1_5pct_Hit  \
# 0          2506793503       40700  1805.0    0.0             1             1
# 1          3143968156       40700  1833.0    0.0             1             1
# 2           589777804       40700  1840.0    0.0             1             1
# 3          2075643376       40700  1844.0    2.0             1             1
# 4           590316517       40700  1844.0    0.0             0             0
# ...               ...         ...     ...    ...           ...           ...
# 160548633  3193903310  2522767166  2022.0    0.0             0             0
# 160548634  3214594834  2522767166  2022.0    0.0             0             0
# 160548635  3197830550  2522767166  2022.0    0.0             0             0
# 160548636  3205739047  2522767166  2022.0    0.0             0             0
# ...

# %%
# %%time
Larger_10 = len(df_MAG_Lv1_Hit.loc[df_MAG_Lv1_Hit['Lv1_10pct_Hit'] == 1, :]) / len(df_MAG_Lv1_Hit)
Larger_5 = len(df_MAG_Lv1_Hit.loc[df_MAG_Lv1_Hit['Lv1_5pct_Hit'] == 1, :]) / len(df_MAG_Lv1_Hit)
Larger_1 = len(df_MAG_Lv1_Hit.loc[df_MAG_Lv1_Hit['Lv1_1pct_Hit'] == 1, :]) / len(df_MAG_Lv1_Hit)
print(Larger_10, Larger_5, Larger_1)
# Out:
# 0.10851862225078483 0.05251258500243396 0.010293428960761412
# CPU times: user 3.69 s, sys: 3.64 s, total: 7.33 s
# Wall time: 7.52 s

# %%
# %%time
from tqdm import tqdm
import copy
Chunks = []
for field, df_group in tqdm(df_MAG_PF_Year_Lv1_GBF):
    # print(field)
    df_MAG_PF_Year_Lv1_GBFY = df_group.groupby(['Year'],as_index=False)
    # for year, df_G in tqdm(df_MAG_PF_Year_Lv0_GBFY):
    for year, df_G in df_MAG_PF_Year_Lv1_GBFY:
        # print(year)
        df_G = df_G.sort_values(by=['C_all'],ascending=False)
        len_df_G = len(df_G)
        
        pct = 0.01
        df_G['Lv1_1pct_Hit'] = 0

        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] > bound_c, 'Lv1_1pct_Hit'] = 1
        
        pct = 0.05
        df_G['Lv1_5pct_Hit'] = 0
        
        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] > bound_c, 'Lv1_5pct_Hit'] = 1
        
        
        pct = 0.10
        df_G['Lv1_10pct_Hit'] = 0
        
        pos = int(pct*len_df_G)
        if pos > 0:
            pos -= 1
        bound_c = df_G.iloc[pos, 3] # C_all is in the 3rd column.
        df_G.loc[df_G['C_all'] > bound_c, 'Lv1_10pct_Hit'] = 1
        
        
        # Chunks.append(copy.deepcopy(df_G))
        Chunks.append(df_G)
        # break
    # break
# df_G
# Out:
# 100%|██████████| 292/292 [03:23<00:00,  1.43it/s]
# CPU times: user 3min 26s, sys: 6.33 s, total: 3min 32s
# Wall time: 3min 32s

# %%
# %%time
df_MAG_Lv1_Hit = pd.concat(Chunks, ignore_index=True)
df_MAG_Lv1_Hit
# Out:
# CPU times: user 10.8 s, sys: 3.06 s, total: 13.8 s
# Wall time: 13.8 s
#                 MAGID     FieldID    Year  C_all  Lv1_1pct_Hit  Lv1_5pct_Hit  \
# 0          2506793503       40700  1805.0    0.0             0             0
# 1          3143968156       40700  1833.0    0.0             0             0
# 2           589777804       40700  1840.0    0.0             0             0
# 3          2075643376       40700  1844.0    2.0             0             0
# 4           590316517       40700  1844.0    0.0             0             0
# ...               ...         ...     ...    ...           ...           ...
# 160548633  3193903310  2522767166  2022.0    0.0             0             0
# 160548634  3214594834  2522767166  2022.0    0.0             0             0
# 160548635  3197830550  2522767166  2022.0    0.0             0             0
# 160548636  3205739047  2522767166  2022.0    0.0             0             0
# ...

# %%
df_MAG_PF_Lv1_Hit_Sel = df_MAG_Lv1_Hit.loc[:,['MAGID','FieldID','Lv1_1pct_Hit','Lv1_5pct_Hit','Lv1_10pct_Hit']]
df_MAG_PF_Lv1_Hit_Sel
# Out:
#                 MAGID     FieldID  Lv1_1pct_Hit  Lv1_5pct_Hit  Lv1_10pct_Hit
# 0          2506793503       40700             0             0              0
# 1          3143968156       40700             0             0              0
# 2           589777804       40700             0             0              0
# 3          2075643376       40700             0             0              0
# 4           590316517       40700             0             0              0
# ...               ...         ...           ...           ...            ...
# 160548633  3193903310  2522767166             0             0              0
# 160548634  3214594834  2522767166             0             0              0
# 160548635  3197830550  2522767166             0             0              0
# 160548636  3205739047  2522767166             0             0              0
# 160548637  3204457722  2522767166             0             0              0
#
# [160548638 rows x 5 columns]

# %%
df_MAG_PF_Lv1_Hit_Sel.loc[df_MAG_PF_Lv1_Hit_Sel['Lv1_10pct_Hit'] == 1, :]
# Out:
#                 MAGID     FieldID  Lv1_1pct_Hit  Lv1_5pct_Hit  Lv1_10pct_Hit
# 266        2044166478       40700             0             0              1
# 317        2044348430       40700             0             0              1
# 346        2329753871       40700             0             0              1
# 368        1558718091       40700             0             0              1
# 397        2079717245       40700             0             0              1
# ...               ...         ...           ...           ...            ...
# 160548185  3209708732  2522767166             0             0              1
# 160548186  3205327997  2522767166             0             0              1
# 160548187  3202361779  2522767166             0             0              1
# 160548188  3140027475  2522767166             0             0              1
# 160548189  3203452221  2522767166             0             0              1
#
# [15393133 rows x 5 columns]

# %%
df_MAG_PF_Lv1_Hit_Sel.to_csv('./Data-Metrics/MAG_PF_Lv1_Hit.csv', sep='\t', index=False)

# %%
# %%time
Smaller_10 = len(df_MAG_Lv1_Hit.loc[df_MAG_Lv1_Hit['Lv1_10pct_Hit'] == 1, :]) / len(df_MAG_Lv1_Hit)
Smaller_5 = len(df_MAG_Lv1_Hit.loc[df_MAG_Lv1_Hit['Lv1_5pct_Hit'] == 1, :]) / len(df_MAG_Lv1_Hit)
Smaller_1 = len(df_MAG_Lv1_Hit.loc[df_MAG_Lv1_Hit['Lv1_1pct_Hit'] == 1, :]) / len(df_MAG_Lv1_Hit)
print(Smaller_10, Smaller_5, Smaller_1)
# Out:
# 0.09587831570393017 0.04829859721388605 0.00958074773577338
# CPU times: user 3.33 s, sys: 3.64 s, total: 6.96 s
# Wall time: 7.05 s

# %%
print(0.1-Smaller_10, Larger_10-0.1)
print(0.05-Smaller_5, Larger_5-0.05)
print(0.01-Smaller_1, Larger_1-0.01)
# Out:
# 0.004121684296069836 0.008518622250784827
# 0.0017014027861139494 0.0025125850024339605
# 0.0004192522642266199 0.0002934289607614115

# %%
len(df_MAG_Lv1_Hit['MAGID'].unique())
# Out:
# 115867760

# %%
# %%time
df_MAG_Lv1_Hit = df_MAG_Lv1_Hit.sort_values(by=['Lv1_1pct_Hit'], ascending=True)
df_MAG_Lv1_Hit = df_MAG_Lv1_Hit.sort_values(by=['Lv1_5pct_Hit'], ascending=True, kind='mergesort')
df_MAG_Lv1_Hit = df_MAG_Lv1_Hit.sort_values(by=['Lv1_10pct_Hit'], ascending=True, kind='mergesort')
df_MAG_Lv1_Hit
# Out:
# CPU times: user 22.5 s, sys: 13.6 s, total: 36.1 s
# Wall time: 36.1 s
#                 MAGID    FieldID    Year  C_all  Lv1_1pct_Hit  Lv1_5pct_Hit  \
# 0          2506793503      40700  1805.0    0.0             0             0
# 106775595  2042204040  138921699  2013.0   10.0             0             0
# 106775596    52324956  138921699  2013.0   10.0             0             0
# 106775597  2029997917  138921699  2013.0   10.0             0             0
# 106775598  1980086535  138921699  2013.0   10.0             0             0
# ...               ...        ...     ...    ...           ...           ...
# 87298710   3122770007  121955636  2016.0  180.0             1             1
# 87298709   2072559981  121955636  2016.0  181.0             1             1
# 87298708   2153894854  121955636  2016.0  184.0             1             1
# 87298717   3125301375  121955636  2016.0  154.0             1             1
# ...

# %%
df_MAG_Lv1_Hit.tail(10)
# Out:
#                MAGID    FieldID    Year  C_all  Lv1_1pct_Hit  Lv1_5pct_Hit  \
# 87298715  2339026732  121955636  2016.0  155.0             1             1
# 87298714  2176518417  121955636  2016.0  160.0             1             1
# 87298713  2286138398  121955636  2016.0  163.0             1             1
# 87298712  2212233521  121955636  2016.0  167.0             1             1
# 87298711  2228927609  121955636  2016.0  176.0             1             1
# 87298710  3122770007  121955636  2016.0  180.0             1             1
# 87298709  2072559981  121955636  2016.0  181.0             1             1
# 87298708  2153894854  121955636  2016.0  184.0             1             1
# 87298717  3125301375  121955636  2016.0  154.0             1             1
# 14748088  1969422869   19417346  2010.0  134.0             1             1
#
#           Lv1_10pct_Hit
# 87298715              1
# 87298714              1
# 87298713              1
# 87298712              1
# ...

# %%
df_MAG_Lv1_Hit.loc[df_MAG_Lv1_Hit['MAGID'] == 2339026732,:]
# Out:
#                 MAGID    FieldID    Year  C_all  Lv1_1pct_Hit  Lv1_5pct_Hit  \
# 130316307  2339026732  162853370  2016.0  155.0             1             1
# 87298715   2339026732  121955636  2016.0  155.0             1             1
#
#            Lv1_10pct_Hit
# 130316307              1
# 87298715               1

# %%
# %%time
df_MAG_Lv1_Hit.drop_duplicates(subset=['MAGID'], keep='last', inplace=True)
df_MAG_Lv1_Hit
# Out:
# CPU times: user 1min 8s, sys: 6.58 s, total: 1min 15s
# Wall time: 1min 15s
#                 MAGID    FieldID    Year  C_all  Lv1_1pct_Hit  Lv1_5pct_Hit  \
# 0          2506793503      40700  1805.0    0.0             0             0
# 106775601  2991296531  138921699  2013.0   10.0             0             0
# 106775610  2031905351  138921699  2013.0   10.0             0             0
# 106775576  1506431262  138921699  2013.0   10.0             0             0
# 106775578  2478891160  138921699  2013.0   10.0             0             0
# ...               ...        ...     ...    ...           ...           ...
# 87298710   3122770007  121955636  2016.0  180.0             1             1
# 87298709   2072559981  121955636  2016.0  181.0             1             1
# 87298708   2153894854  121955636  2016.0  184.0             1             1
# 87298717   3125301375  121955636  2016.0  154.0             1             1
# ...

# %%
# %%time
df_MAG_Lv1_Hit_Sel = df_MAG_Lv1_Hit.loc[:,['MAGID','Lv1_1pct_Hit','Lv1_5pct_Hit','Lv1_10pct_Hit']]
df_MAG_Lv1_Hit_Sel
# Out:
# CPU times: user 643 ms, sys: 833 ms, total: 1.48 s
# Wall time: 1.47 s
#                 MAGID  Lv1_1pct_Hit  Lv1_5pct_Hit  Lv1_10pct_Hit
# 0          2506793503             0             0              0
# 106775601  2991296531             0             0              0
# 106775610  2031905351             0             0              0
# 106775576  1506431262             0             0              0
# 106775578  2478891160             0             0              0
# ...               ...           ...           ...            ...
# 87298710   3122770007             1             1              1
# 87298709   2072559981             1             1              1
# 87298708   2153894854             1             1              1
# 87298717   3125301375             1             1              1
# 14748088   1969422869             1             1              1
#
# [115867760 rows x 4 columns]

# %%
df_MAG_Lv1_Hit_Sel.to_csv('./Data-Metrics/MAG_Lv1_Hit.csv', sep='\t', index=False)

# %%
df_MAG_Lv1_Hit
# Out:
#                 MAGID    FieldID    Year  C_all  Lv1_1pct_Hit  Lv1_5pct_Hit  \
# 0          2506793503      40700  1805.0    0.0             0             0
# 106775601  2991296531  138921699  2013.0   10.0             0             0
# 106775610  2031905351  138921699  2013.0   10.0             0             0
# 106775576  1506431262  138921699  2013.0   10.0             0             0
# 106775578  2478891160  138921699  2013.0   10.0             0             0
# ...               ...        ...     ...    ...           ...           ...
# 87298710   3122770007  121955636  2016.0  180.0             1             1
# 87298709   2072559981  121955636  2016.0  181.0             1             1
# 87298708   2153894854  121955636  2016.0  184.0             1             1
# 87298717   3125301375  121955636  2016.0  154.0             1             1
# 14748088   1969422869   19417346  2010.0  134.0             1             1
#
#            Lv1_10pct_Hit
# 0                      0
# ...

# %% [markdown]
# # Normalized citation

# %%
df_MAG_PF_Year_Lv0
# Out:
#                 MAGID    FieldID    Year  C_all
# 0            18936224   71924100  2009.0   11.0
# 1            94748468  144024400  2000.0    0.0
# 2           113998959   71924100  2003.0    6.0
# 3            56740461  144133560  1995.0    5.0
# 4                  23   71924100  2012.0    2.0
# ...               ...        ...     ...    ...
# 116942136  3204507145   41008148  2021.0    0.0
# 116942137  3204507150  185592680  2022.0    0.0
# 116942138  3204507160   71924100  2021.0    0.0
# 116942139  3204507164   71924100  2021.0    0.0
# 116942140  3204507171  144133560  2021.0    0.0
#
# [116937951 rows x 4 columns]

# %%
df_MAG_PF_Year_Lv1
# Out:
#                 MAGID    FieldID    Year  C_all
# 0            94748468   95124753  2000.0    0.0
# 1            94748468   36289849  2000.0    0.0
# 2           113998959  112930515  2003.0    6.0
# 3           113998959  141071460  2003.0    6.0
# 4                  23  177713679  2012.0    2.0
# ...               ...        ...     ...    ...
# 160552848  3204507150  188027245  2022.0    0.0
# 160552849  3204507160  187212893  2021.0    0.0
# 160552850  3204507164  143998085  2021.0    0.0
# 160552851  3204507164  126322002  2021.0    0.0
# 160552852  3204507171   34447519  2021.0    0.0
#
# [160548638 rows x 4 columns]

# %%
df_MAG_PF_Year_Lv0_GBF = df_MAG_PF_Year_Lv0.groupby(['FieldID'],as_index=False)
df_MAG_PF_Year_Lv1_GBF = df_MAG_PF_Year_Lv1.groupby(['FieldID'],as_index=False)

# %% [markdown]
# ## Cf in Lv0 field

# %%
# %%time
from tqdm import tqdm
import copy
Chunks = []
for field, df_group in tqdm(df_MAG_PF_Year_Lv0_GBF):
    # print(field)
    df_MAG_PF_Year_Lv0_GBFY = df_group.groupby(['Year'],as_index=False)
    # for year, df_G in tqdm(df_MAG_PF_Year_Lv0_GBFY):
    for year, df_G in df_MAG_PF_Year_Lv0_GBFY:
        c_0 = df_G['C_all'].sum() / len(df_G)
        df_G['Lv0_Cf'] = df_G['C_all'] / c_0
        Chunks.append(df_G)
# Out:
# 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# CPU times: user 19.1 s, sys: 2.01 s, total: 21.1 s
# Wall time: 21.1 s

# %%
df_G['Lv0_Cf'].sum()
# Out:
# 1300.0

# %%
df_G['C_all'].sum()
# Out:
# 152.0

# %%
# %%time
df_MAG_Lv0_Cf = pd.concat(Chunks, ignore_index=True)
df_MAG_Lv0_Cf
# Out:
# CPU times: user 1.67 s, sys: 1.31 s, total: 2.97 s
# Wall time: 3 s
#                 MAGID    FieldID    Year  C_all     Lv0_Cf
# 0           638928283   15744967  1800.0    0.0   0.000000
# 1           615929232   15744967  1800.0    0.0   0.000000
# 2          1597528871   15744967  1800.0    0.0   0.000000
# 3          2039565325   15744967  1800.0    0.0   0.000000
# 4          2125825908   15744967  1800.0    2.0  22.500000
# ...               ...        ...     ...    ...        ...
# 116937946  3204458357  205649164  2022.0    0.0   0.000000
# 116937947  3204460996  205649164  2022.0    0.0   0.000000
# 116937948  3217792559  205649164  2022.0    0.0   0.000000
# 116937949  3204483141  205649164  2022.0    2.0  17.105263
# 116937950  3217810235  205649164  2022.0    0.0   0.000000
#
# [116937951 rows x 5 columns]

# %%
df_MAG_Lv0_Cf
# Out:
#                 MAGID    FieldID    Year  C_all     Lv0_Cf
# 0           638928283   15744967  1800.0    0.0   0.000000
# 1           615929232   15744967  1800.0    0.0   0.000000
# 2          1597528871   15744967  1800.0    0.0   0.000000
# 3          2039565325   15744967  1800.0    0.0   0.000000
# 4          2125825908   15744967  1800.0    2.0  22.500000
# ...               ...        ...     ...    ...        ...
# 116937946  3204458357  205649164  2022.0    0.0   0.000000
# 116937947  3204460996  205649164  2022.0    0.0   0.000000
# 116937948  3217792559  205649164  2022.0    0.0   0.000000
# 116937949  3204483141  205649164  2022.0    2.0  17.105263
# 116937950  3217810235  205649164  2022.0    0.0   0.000000
#
# [116937951 rows x 5 columns]

# %%
df_MAG_Lv0_Cf.loc[df_MAG_Lv0_Cf['Year'] == 2010, :]
# Out:
#                 MAGID    FieldID    Year  C_all    Lv0_Cf
# 2808239     132792176   15744967  2010.0    0.0  0.000000
# 2808240      94751772   15744967  2010.0    4.0  0.203546
# 2808241     170366608   15744967  2010.0   13.0  0.661525
# 2808242      56747112   15744967  2010.0    0.0  0.000000
# 2808243     151251167   15744967  2010.0    7.0  0.356206
# ...               ...        ...     ...    ...       ...
# 115768336  3200421820  205649164  2010.0    0.0  0.000000
# 115768337  3213171014  205649164  2010.0    0.0  0.000000
# 115768338  3200429841  205649164  2010.0    6.0  0.769450
# 115768339  3200462653  205649164  2010.0    0.0  0.000000
# 115768340  3204458737  205649164  2010.0    1.0  0.128242
#
# [3841252 rows x 5 columns]

# %%
df_MAG_Lv0_Cf_test = df_MAG_Lv0_Cf.loc[(df_MAG_Lv0_Cf['Year'] == 2010) & (df_MAG_Lv0_Cf['FieldID'] == 15744967) , :]
df_MAG_Lv0_Cf_test
# Out:
#               MAGID   FieldID    Year  C_all    Lv0_Cf
# 2808239   132792176  15744967  2010.0    0.0  0.000000
# 2808240    94751772  15744967  2010.0    4.0  0.203546
# 2808241   170366608  15744967  2010.0   13.0  0.661525
# 2808242    56747112  15744967  2010.0    0.0  0.000000
# 2808243   151251167  15744967  2010.0    7.0  0.356206
# ...             ...       ...     ...    ...       ...
# 2996214  3204413612  15744967  2010.0    0.0  0.000000
# 2996215  3217741369  15744967  2010.0    0.0  0.000000
# 2996216  3213277185  15744967  2010.0    0.0  0.000000
# 2996217  3204445543  15744967  2010.0    0.0  0.000000
# 2996218  3204475774  15744967  2010.0    0.0  0.000000
#
# [187980 rows x 5 columns]

# %%
df_MAG_Lv0_Cf_test['C_all'].sum(), len(df_MAG_Lv0_Cf_test)
# Out:
# (3694102.0, 187980)

# %%
df_MAG_Lv0_Cf_test['C_all'].sum() / len(df_MAG_Lv0_Cf_test)
# Out:
# 19.651569315884668

# %%
df_MAG_Lv0_Cf_Sel = df_MAG_Lv0_Cf.loc[:,['MAGID','FieldID','Lv0_Cf']]
df_MAG_Lv0_Cf_Sel
# Out:
#                 MAGID    FieldID     Lv0_Cf
# 0           638928283   15744967   0.000000
# 1           615929232   15744967   0.000000
# 2          1597528871   15744967   0.000000
# 3          2039565325   15744967   0.000000
# 4          2125825908   15744967  22.500000
# ...               ...        ...        ...
# 116937946  3204458357  205649164   0.000000
# 116937947  3204460996  205649164   0.000000
# 116937948  3217792559  205649164   0.000000
# 116937949  3204483141  205649164  17.105263
# 116937950  3217810235  205649164   0.000000
#
# [116937951 rows x 3 columns]

# %%
df_MAG_Lv0_Cf_Sel
# Out:
#                 MAGID    FieldID     Lv0_Cf
# 0           638928283   15744967   0.000000
# 1           615929232   15744967   0.000000
# 2          1597528871   15744967   0.000000
# 3          2039565325   15744967   0.000000
# 4          2125825908   15744967  22.500000
# ...               ...        ...        ...
# 116937946  3204458357  205649164   0.000000
# 116937947  3204460996  205649164   0.000000
# 116937948  3217792559  205649164   0.000000
# 116937949  3204483141  205649164  17.105263
# 116937950  3217810235  205649164   0.000000
#
# [116937951 rows x 3 columns]

# %%
df_MAG_Lv0_Cf_Sel.to_csv('./Data-Metrics/MAG_PF_Lv0_Cf.csv', sep='\t', index=False)

# %% [markdown]
# ## Cf in Lv1 field

# %%
# %%time
from tqdm import tqdm
import copy
Chunks = []
for field, df_group in tqdm(df_MAG_PF_Year_Lv1_GBF):
    # print(field)
    df_MAG_PF_Year_Lv1_GBFY = df_group.groupby(['Year'],as_index=False)
    # for year, df_G in tqdm(df_MAG_PF_Year_Lv0_GBFY):
    for year, df_G in df_MAG_PF_Year_Lv1_GBFY:
        c_0 = df_G['C_all'].sum() / len(df_G)
        df_G['Lv1_Cf'] = df_G['C_all'] / c_0
        Chunks.append(df_G)
# Out:
# 100%|██████████| 292/292 [01:06<00:00,  4.42it/s]
# CPU times: user 1min 3s, sys: 3.7 s, total: 1min 7s
# Wall time: 1min 6s

# %%
# %%time
df_MAG_Lv1_Cf = pd.concat(Chunks, ignore_index=True)
df_MAG_Lv1_Cf
# Out:
# CPU times: user 8.28 s, sys: 2.19 s, total: 10.5 s
# Wall time: 10.5 s
#                 MAGID     FieldID    Year  C_all  Lv1_Cf
# 0          2506793503       40700  1805.0    0.0     NaN
# 1          3143968156       40700  1833.0    0.0     NaN
# 2           589777804       40700  1840.0    0.0     NaN
# 3           590316517       40700  1844.0    0.0     0.0
# 4          2075643376       40700  1844.0    2.0     2.0
# ...               ...         ...     ...    ...     ...
# 160548633  3217679531  2522767166  2022.0    0.0     0.0
# 160548634  3213207215  2522767166  2022.0    0.0     0.0
# 160548635  3196743356  2522767166  2022.0    0.0     0.0
# 160548636  3217764098  2522767166  2022.0    0.0     0.0
# 160548637  3204457722  2522767166  2022.0    0.0     0.0
#
# [160548638 rows x 5 columns]

# %%
df_MAG_Lv1_Cf.loc[df_MAG_Lv1_Cf['Year'] == 2010, :]
# Out:
#                 MAGID     FieldID    Year  C_all    Lv1_Cf
# 119559       56740701       40700  2010.0    3.0  0.315213
# 119560            549       40700  2010.0    0.0  0.000000
# 119561      132861496       40700  2010.0    0.0  0.000000
# 119562      132922987       40700  2010.0    2.0  0.210142
# 119563      170567008       40700  2010.0    0.0  0.000000
# ...               ...         ...     ...    ...       ...
# 160347249  3206513231  2522767166  2010.0    1.0  0.039079
# 160347250  3202356773  2522767166  2010.0    0.0  0.000000
# 160347251  3202891674  2522767166  2010.0    1.0  0.039079
# 160347252  3216738840  2522767166  2010.0    0.0  0.000000
# 160347253  3217625767  2522767166  2010.0    1.0  0.039079
#
# [5705468 rows x 5 columns]

# %%
df_MAG_Lv1_Cf_test = df_MAG_Lv1_Cf.loc[(df_MAG_Lv1_Cf['Year'] == 2010) & (df_MAG_Lv1_Cf['FieldID'] == 40700) , :]
df_MAG_Lv1_Cf_test
# Out:
#              MAGID  FieldID    Year  C_all    Lv1_Cf
# 119559    56740701    40700  2010.0    3.0  0.315213
# 119560         549    40700  2010.0    0.0  0.000000
# 119561   132861496    40700  2010.0    0.0  0.000000
# 119562   132922987    40700  2010.0    2.0  0.210142
# 119563   170567008    40700  2010.0    0.0  0.000000
# ...            ...      ...     ...    ...       ...
# 133360  3208241433    40700  2010.0    0.0  0.000000
# 133361  3203659245    40700  2010.0    0.0  0.000000
# 133362  3217133675    40700  2010.0    0.0  0.000000
# 133363  3208810930    40700  2010.0    0.0  0.000000
# 133364  3200447103    40700  2010.0    2.0  0.210142
#
# [13806 rows x 5 columns]

# %%
df_MAG_Lv1_Cf_test['C_all'].sum() / len(df_MAG_Lv1_Cf_test)
# Out:
# 9.517383746197305

# %%
# %%time
df_MAG_Lv1_Cf.fillna(0, inplace=True)
df_MAG_Lv1_Cf
# Out:
# CPU times: user 811 ms, sys: 2.31 ms, total: 813 ms
# Wall time: 813 ms
#                 MAGID     FieldID    Year  C_all  Lv1_Cf
# 0          2506793503       40700  1805.0    0.0     0.0
# 1          3143968156       40700  1833.0    0.0     0.0
# 2           589777804       40700  1840.0    0.0     0.0
# 3           590316517       40700  1844.0    0.0     0.0
# 4          2075643376       40700  1844.0    2.0     2.0
# ...               ...         ...     ...    ...     ...
# 160548633  3217679531  2522767166  2022.0    0.0     0.0
# 160548634  3213207215  2522767166  2022.0    0.0     0.0
# 160548635  3196743356  2522767166  2022.0    0.0     0.0
# 160548636  3217764098  2522767166  2022.0    0.0     0.0
# 160548637  3204457722  2522767166  2022.0    0.0     0.0
#
# [160548638 rows x 5 columns]

# %%
df_MAG_Lv1_Cf_Sel = df_MAG_Lv1_Cf.loc[:,['MAGID','FieldID','Lv1_Cf']]
df_MAG_Lv1_Cf_Sel
# Out:
#                 MAGID     FieldID  Lv1_Cf
# 0          2506793503       40700     0.0
# 1          3143968156       40700     0.0
# 2           589777804       40700     0.0
# 3           590316517       40700     0.0
# 4          2075643376       40700     2.0
# ...               ...         ...     ...
# 160548633  3217679531  2522767166     0.0
# 160548634  3213207215  2522767166     0.0
# 160548635  3196743356  2522767166     0.0
# 160548636  3217764098  2522767166     0.0
# 160548637  3204457722  2522767166     0.0
#
# [160548638 rows x 3 columns]

# %%
df_MAG_Lv1_Cf_Sel.loc[df_MAG_Lv1_Cf_Sel['Lv1_Cf'] > 0,:]
# Out:
#                 MAGID     FieldID     Lv1_Cf
# 4          2075643376       40700   2.000000
# 6          2802053976       40700   1.000000
# 8          2518537736       40700   1.000000
# 10         1561675275       40700   1.000000
# 14         2113671298       40700   2.000000
# ...               ...         ...        ...
# 160548574  3200008032  2522767166   5.951220
# 160548597  3217331066  2522767166  11.902439
# 160548614  3204189188  2522767166   5.951220
# 160548619  3196572840  2522767166   5.951220
# 160548626  3196640045  2522767166   5.951220
#
# [95118649 rows x 3 columns]

# %%
df_MAG_Lv1_Cf_Sel
# Out:
#                 MAGID     FieldID  Lv1_Cf
# 0          2506793503       40700     0.0
# 1          3143968156       40700     0.0
# 2           589777804       40700     0.0
# 3           590316517       40700     0.0
# 4          2075643376       40700     2.0
# ...               ...         ...     ...
# 160548633  3217679531  2522767166     0.0
# 160548634  3213207215  2522767166     0.0
# 160548635  3196743356  2522767166     0.0
# 160548636  3217764098  2522767166     0.0
# 160548637  3204457722  2522767166     0.0
#
# [160548638 rows x 3 columns]

# %%
df_MAG_Lv1_Cf_Sel.to_csv('./Data-Metrics/MAG_PF_Lv1_Cf.csv', sep='\t', index=False)
