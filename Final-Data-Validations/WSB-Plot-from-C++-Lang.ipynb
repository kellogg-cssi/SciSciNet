# %%
import pandas
import numpy as np

# %%
MAPE = np.array([0.0204225,
0.0314518,
0.04083,
0.0493032,
0.0570563,
0.0643574,
0.0716549,
0.0787285,
0.085277,
0.0914057,
0.097377,
0.103097,
0.108627,
0.114086,
0.119344,
0.124384,
0.129275,
0.134154,
0.138898,
0.143807])
MAPE
# Out:
# array([0.0204225, 0.0314518, 0.04083  , 0.0493032, 0.0570563, 0.0643574,
#        0.0716549, 0.0787285, 0.085277 , 0.0914057, 0.097377 , 0.103097 ,
#        0.108627 , 0.114086 , 0.119344 , 0.124384 , 0.129275 , 0.134154 ,
#        0.138898 , 0.143807 ])

# %%
Acc = np.array([
0.988442,
0.961776,
0.919497,
0.867941,
0.821961,
0.780898,
0.742016,
0.707543,
0.67662,
0.650208,
0.627649,
0.606712,
0.588411,
0.573456,
0.555105,
0.542178,
0.530214,
0.517692,
0.504056,
0.492142,
])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import host_subplot
import matplotlib.ticker as ticker
fig = plt.figure(figsize=(5,5),facecolor='white')

col1 = '#F7602A'
col2 = '#4E2A84'

par1 = host_subplot(111)
plt.subplots_adjust(right=1)

host = par1.twinx()
# par1.tick_params(axis='x', which='both',bottom='on',top='off')
x = np.arange(20) + 1

host.plot(x, MAPE, label="MAPE",color=col1, marker="s",)
par1.plot(x, Acc, label="Accuracy",color=col2, marker="^",)
# host.fill_between(x, np.array(Da)*100, np.array(Db)*100, color='gray', alpha=0.15)
# par1.fill_between(x, Ca, Cb, color='gray', alpha=0.15)

host.set_xlim(0, 21)
host.set_ylim(0,0.4)
# host.set_yticks([30,40,50,60,70])
par1.set_ylim(0.0,1.0)
# par1.set_yticks([20,25,30,35,40])
# host.set_xticks([2,4,6,8])
# par1.set_xticks([2,4,6,8])
par1.set_xlabel('Years after training period',size=16)
host.set_ylabel('MAPE',size=16)
par1.set_ylabel('Accuracy',size=16)
host.tick_params(axis='y', which='major', labelsize=12, direction='in', labelcolor=col1)
par1.tick_params(axis='y', which='major', labelsize=12, direction='in', labelcolor=col2)
host.spines['top'].set_visible(False)
par1.spines['top'].set_visible(False)
host.yaxis.label.set_color(col1)
par1.yaxis.label.set_color(col2)
host.tick_params(axis='x', which='major', labelsize=12, direction='in')
par1.tick_params(axis='x', which='major', labelsize=12, direction='in')

host.xaxis.set_minor_locator(ticker.IndexLocator(base=2.5, offset=-1))
host.tick_params(axis='x', which='minor', direction='in')
# par1.xaxis.set_minor_locator(ticker.IndexLocator(base=1, offset=1))
# par1.tick_params(axis='x', which='minor', direction='in')
# plt.tight_layout()
#plt.savefig('~/Fig2a.pdf')
plt.savefig('./Validation-Figures/WSB_15y_m30.pdf', bbox_inches="tight")

# %%
# g++ -o main main.cpp adv_mic_predict.cpp
# ./main ../para_est/para7.txt 15
