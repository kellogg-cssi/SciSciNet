# %%
import pandas as pd
import csv
date_str = '2021-12-06'

# %%
# %%time

df_MAG_ConfS = pd.read_csv('../../MAG_'+date_str+'/mag/ConferenceSeries.txt', 
                              sep='\t', header=None, quoting=csv.QUOTE_NONE)

df_MAG_ConfS
# Out:
# CPU times: user 17.3 ms, sys: 3.07 ms, total: 20.4 ms
# Wall time: 57.7 ms
#                0      1               2  \
# 0     1134804816  12841           ICIDS
# 1     1165160117  14759         SWAT4LS
# 2     1192093291  12295      TRIDENTCOM
# 3     1199066382   9960  BIOINFORMATICS
# 4     1201746639  15369             AIS
# ...          ...    ...             ...
# 4546  2754809603  14488            IPSS
# 4547  2756271167  13536            ECMS
# 4548  2756896743  17858             CAI
# 4549  2757378734  15093      UPGRADE-CN
# 4550  2898205804  18225          ER(ZR)
#
#                                                       3      4      5      6  \
# 0     International Conference on Interactive Digita...    608    607   3156
# 1     Semantic Web Applications and Tools for Life S...     88     88    242
# 2     Testbeds and Research Infrastructures for the ...    571    571   5264
# 3            International Conference on Bioinformatics  13424  13424  19178
# ...

# %%
# %%time
SciNet_ConferenceSeries = df_MAG_ConfS.loc[:,[0,2,3]]
SciNet_ConferenceSeries
# Out:
# CPU times: user 2.01 ms, sys: 0 ns, total: 2.01 ms
# Wall time: 1.92 ms
#                0               2  \
# 0     1134804816           ICIDS
# 1     1165160117         SWAT4LS
# 2     1192093291      TRIDENTCOM
# 3     1199066382  BIOINFORMATICS
# 4     1201746639             AIS
# ...          ...             ...
# 4546  2754809603            IPSS
# 4547  2756271167            ECMS
# 4548  2756896743             CAI
# 4549  2757378734      UPGRADE-CN
# 4550  2898205804          ER(ZR)
#
#                                                       3
# 0     International Conference on Interactive Digita...
# 1     Semantic Web Applications and Tools for Life S...
# 2     Testbeds and Research Infrastructures for the ...
# 3            International Conference on Bioinformatics
# 4                    Autonomous and Intelligent Systems
# ...                                                 ...
# 4546         IEEE International Power Sources Symposium
# ...

# %%
SciNet_ConferenceSeries.columns = ['ConferenceSeriesID','Abbr_Name','ConferenceSeries_Name']
SciNet_ConferenceSeries
# Out:
#       ConferenceSeriesID       Abbr_Name  \
# 0             1134804816           ICIDS
# 1             1165160117         SWAT4LS
# 2             1192093291      TRIDENTCOM
# 3             1199066382  BIOINFORMATICS
# 4             1201746639             AIS
# ...                  ...             ...
# 4546          2754809603            IPSS
# 4547          2756271167            ECMS
# 4548          2756896743             CAI
# 4549          2757378734      UPGRADE-CN
# 4550          2898205804          ER(ZR)
#
#                                   ConferenceSeries_Name
# 0     International Conference on Interactive Digita...
# 1     Semantic Web Applications and Tools for Life S...
# 2     Testbeds and Research Infrastructures for the ...
# 3            International Conference on Bioinformatics
# 4                    Autonomous and Intelligent Systems
# ...                                                 ...
# 4546         IEEE International Power Sources Symposium
# ...

# %%
# SciNet_ConferenceSeries.to_csv('../Final-SciNet-Tables/SciNet_ConferenceSeries.tsv', sep='\t', index=False)

# %%
SciNet_ConferenceSeries_New = pd.read_csv('../Final-SciNet-Tables/SciNet_ConferenceSeries.tsv', sep='\t')
SciNet_ConferenceSeries_New
# Out:
#       ConferenceSeriesID       Abbr_Name  \
# 0             1134804816           ICIDS
# 1             1165160117         SWAT4LS
# 2             1192093291      TRIDENTCOM
# 3             1199066382  BIOINFORMATICS
# 4             1201746639             AIS
# ...                  ...             ...
# 4546          2754809603            IPSS
# 4547          2756271167            ECMS
# 4548          2756896743             CAI
# 4549          2757378734      UPGRADE-CN
# 4550          2898205804          ER(ZR)
#
#                                   ConferenceSeries_Name
# 0     International Conference on Interactive Digita...
# 1     Semantic Web Applications and Tools for Life S...
# 2     Testbeds and Research Infrastructures for the ...
# 3            International Conference on Bioinformatics
# 4                    Autonomous and Intelligent Systems
# ...                                                 ...
# 4546         IEEE International Power Sources Symposium
# ...
